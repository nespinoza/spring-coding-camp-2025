# %% [markdown]
# ### April 24

# %% [markdown]
# # REGULAR EXPRESSIONS (regex) 🤖

# %% [markdown]
# Is a library that collects a set of tools that allow us to **search**, **match**, and **manipulate** text based on patterns, and not on exact words or phrases.
#
# In Python, this library is called *re*.

# %% [markdown]
# ### Basic Functions
# | **Function**   | **What it does**                                     |
# |----------------|------------------------------------------------------ |
# | `re.match()`   | Checks if the beginning of a string matches a pattern.|
# | `re.search()`  | Looks for the first match anywhere in the string.     |
# | `re.findall()` | Finds all matches in the string.                      |
# | `re.sub()`     | Replaces parts of the string.                         |

# %% [markdown]
# ### Basic Syntax
# | **Symbol** | **Meaning**                                       | **Example** | **What it matches**                          |
# |------------|---------------------------------------------------|-------------|----------------------------------------------|
# | `.`        | Any character except newline                      | `a.b`       | `acb`, `a_b`, `a7b`                          |
# | `\d`       | A digit (0-9)                                      | `\d\d`      | `23`, `45`                                  |
# | `\w`       | A word character (letter, digit, or underscore)    | `\w+`       | `abc`, `hello_123`                           |
# | `\s`       | A whitespace character (space, tab, newline)       | `\s`        | `' '` (a space)                              |
# | `\.`       | means a real dot                                   | `\.`       | `a.c`, `hello.com`                           |
# |

# %% [markdown]
# ### 💬 Matching and Capturing
# 📍Matching= The regex found something that fits your pattern.
# - [^>]* = match any characters that are NOT >, as many as possible
#
# 🔄 Capturing = You told the regex to "save this part" using parentheses ()
# - ([^<]+) = captures the inner text (any characters except '<')
#
# **Sooo, only the part inside parentheses (...) is captured and returned in group**

# %% [markdown]
# ## Task 1

# %%
# Library

import re
from re import findall

# %%
# open document

mails = open('ex1.txt','r')
content = mails.read()
print(content)

# %%
# Extract only the mails found in the txt document ex1

R = re.findall(r'[\w.-]+@\w+\.\w+', content)

# %%
print(R)

# %% [markdown]
# ## Task 2

# %%
# link = https://www.stsci.edu/stsci-research/research-directory

code = open('mails stsci.txt','r')

# %%
redirectory = code.read()
print(redirectory)

# %% [markdown]
# **2.1 Create a list with mails**

# %%
part_mails = re.findall(r'>\w+<br', redirectory)

# %%
print(part_mails)

# %%
# Replace the pattern > and <br for a space using sub function

clean_mail= [re.sub(r'>|<br', '', mail) for mail in part_mails] 

# sub replace part of the string with '' 
# | mean "or" in Regex. Son in this case (>|<br) help us to replace 2 characteres in the same line of code

# %%
clean_mail
# Out:
# ['kalatalo',
#  'aloisi',
#  'jayander',
#  'tbeck',
#  'bellini',
#  'boeker',
#  'bohlin',
#  'mboyer',
#  'cbritt',
#  'tbrown',
#  'calamida',
#  'jcarlberg',
#  'stefano',
#  'chayer',
#  'cchen',
#  'marcoc',
#  'carolc',
#  'dcoe',
#  'gderosa',
#  'debes',
#  'dixon',
#  'ferguson',
#  'flanagan',
#  'afox',
#  'ofox',
#  'friedman',
#  'fruchter',
#  'fullerton',
#  'gennaro',
#  'kgilbert',
#  'golim',
#  'kgordon',
#  'goudfroo',
#  'jgreen',
#  'nagrogin',
#  'nhathi',
#  'ahenry',
#  'hines',
#  'bholler',
#  'bjames',
#  'kassin',
#  'keyes',
#  'koekemoer',
#  'gak',
#  'slamassa',
#  'dlaw',
#  'lawton',
#  'leitherer',
#  'nlevenson',
#  'long',
#  'lubow',
#  'mackenty',
#  'duccio',
#  'emarcucci',
#  'maca',
#  'pmcc',
#  'mclean',
#  'amaya',
#  'muzerol',
#  'nelan',
#  'anoriega',
#  'norman',
#  'pogle',
#  'osten',
#  'bosullivan',
#  'jegpeek',
#  'molly',
#  'mperrin',
#  'npirzkal',
#  'postman',
#  'proffitt',
#  'pueyo',
#  'mrafelski',
#  'mregan',
#  'inr',
#  'arest',
#  'ariess',
#  'robberto',
#  'duval',
#  'rryan',
#  'ksahu',
#  'rsankrit',
#  'sargent',
#  'sembach',
#  'sirianni',
#  'anand',
#  'gcsloan',
#  'lsmith',
#  'drs',
#  'tsohn',
#  'sonnentr',
#  'soummer',
#  'jstans',
#  'mstiavel',
#  'strolger',
#  'mplate',
#  'etollerud',
#  'tumlinson',
#  'valenti',
#  'marel',
#  'volk',
#  'dwelty',
#  'rlw',
#  'whitmore',
#  'wblair',
#  'lbradley',
#  'fleming',
#  'jgirard',
#  'skendrew',
#  'smullally',
#  'mutchler',
#  'sparks',
#  'cpacifici',
#  'zeidler',
#  'lucas',
#  'cclark',
#  'dfrench',
#  'mdecleir',
#  'sdieterich',
#  'nespinoza',
#  'kumari',
#  'mrevalski',
#  'krowlands',
#  'lwatkins',
#  'jowu',
#  'mmehdipour',
#  'nnikolov',
#  'epor',
#  'emanjavacas',
#  'nindriolo',
#  'pbennet',
#  'tgull',
#  'mmingozzi',
#  'mntampaka',
#  'jpierel',
#  'apetric',
#  'shernandez',
#  'tfischer',
#  'jpegues',
#  'cmurray1',
#  'kilarson',
#  'dsom',
#  'ganand',
#  'nflagey',
#  'lojones',
#  'mtea',
#  'ldsantos',
#  'cjohnson1',
#  'alucy',
#  'phuwe',
#  'jaguilar',
#  'avila',
#  'mburger',
#  'mcara',
#  'kconroy',
#  'jfilippazzo',
#  'mhami',
#  'jhargis',
#  'amjones',
#  'mmarinelli',
#  'tmonroe',
#  'pena',
#  'drodriguez',
#  'ryon',
#  'asahoo',
#  'gwahlgren',
#  'jyoon',
#  'rbeaton',
#  'eschlafly',
#  'bmeena',
#  'ijung',
#  'bmmorris',
#  'khoch',
#  'chevans',
#  'Nota',
#  'jsandez',
#  'msiebert',
#  'ssharma',
#  'apagul',
#  'dstark',
#  'abeckett',
#  'etarantino',
#  'agressier',
#  'hbish',
#  'chawcroft',
#  'mshahbandeh',
#  'rpourcelot',
#  'tberger',
#  'bright',
#  'sgoldman',
#  'lmiller',
#  'mnguyen',
#  'rosteen',
#  'tpauly',
#  'shaw',
#  'ispitzer',
#  'rswaters',
#  'mteodore',
#  'ctodd',
#  'shasselquist',
#  'jlee',
#  'sbetti',
#  'ssteiger',
#  'bvanderhoof',
#  'smirshra',
#  'dcoulter',
#  'yung',
#  'aranjan',
#  'malam',
#  'jlothringer',
#  'jrodriguez',
#  'aacarter',
#  'astroe',
#  'iwong',
#  'gstrampelli',
#  'cgunasekera',
#  'mgriggio',
#  'dmaschmann',
#  'abidot',
#  'jderkacy',
#  'agomez',
#  'dfadda',
#  'jih',
#  'rrickardsvaught',
#  'asmercina',
#  'iescala',
#  'cerba',
#  'fhasan',
#  'bsebastian',
#  'kcrotts',
#  'rlevy',
#  'kmcquinn',
#  'tbrandt',
#  'igoovaerts',
#  'amadurowicz',
#  'dorazio',
#  'mholmberg',
#  'mgarciavalle',
#  'hdiamondlowe',
#  'csoto',
#  'lotz',
#  'norman',
#  'gnoirot',
#  'hbushouse',
#  'sosey']

# %%
# add @stsci.com to the string

real_mail= [name+"@stsci.com" for name in clean_mail]
real_mail

# %%
print("Total Mails = " + str(len(real_mail)))
# Out:
# Total Mails = 245

# %% [markdown]
# **2.2 Create a list with names**

# %% [markdown]
# In this case, I identified three different patterns to extract the names. I created three separate lists based on these patterns, and after cleaning the data, I merged them into a single list.

# %% [markdown]
# List # 1

# %%
part_names1 = re.findall(r'\w+\,\s*\w+</a></td>', redirectory)

# %%
part_names1
# Out:
# ['Alatalo, Katey</a></td>',
#  'Aloisi, Alessandra</a></td>',
#  'Anderson, Jay</a></td>',
#  'Beck, Tracy</a></td>',
#  'Bellini, Andrea</a></td>',
#  'Boeker, Torsten</a></td>',
#  'Boyer, Martha</a></td>',
#  'Britt, Christopher</a></td>',
#  'Brown, Robert</a></td>',
#  'Calamida, Annalisa</a></td>',
#  'Carlberg, Joleen</a></td>',
#  'Chen, Christine</a></td>',
#  'Chiaberge, Marco</a></td>',
#  'Christian, Carol</a></td>',
#  'Coe, Dan</a></td>',
#  'Fox, Andrew</a></td>',
#  'Fox, Ori</a></td>',
#  'Fullerton, Alex</a></td>',
#  'Gennaro, Mario</a></td>',
#  'Gilbert, Karoline</a></td>',
#  'Gordon, Karl</a></td>',
#  'Goudfrooij, Paul</a></td>',
#  'Hathi, Nimish</a></td>',
#  'Henry, Alaina</a></td>',
#  'Hines, Dean</a></td>',
#  'Holler, Bryan</a></td>',
#  'James, Bethan</a></td>',
#  'Kassin, Susan</a></td>',
#  'Koekemoer, Anton</a></td>',
#  'Kriss, Gerard</a></td>',
#  'LaMassa, Stephanie</a></td>',
#  'Law, David</a></td>',
#  'Lawton, Brandon</a></td>',
#  'Leitherer, Claus</a></td>',
#  'Levenson, Nancy</a></td>',
#  'Long, Knox</a></td>',
#  'Lubow, Steve</a></td>',
#  'MacKenty, John</a></td>',
#  'Marcucci, Emma</a></td>',
#  'McCullough, Peter</a></td>',
#  'McLean, Brian</a></td>',
#  'Martin, Amaya</a></td>',
#  'Page, James</a></td>',
#  'Crespo, Alberto</a></td>',
#  'Ogle, Patrick</a></td>',
#  'Osten, Rachel</a></td>',
#  'Peek, Joshua</a></td>',
#  'Peeples, Molly</a></td>',
#  'Pirzkal, Nor</a></td>',
#  'Postman, Marc</a></td>',
#  'Proffitt, Charles</a></td>',
#  'Pueyo, Laurent</a></td>',
#  'Rafelski, Marc</a></td>',
#  'Rest, Armin</a></td>',
#  'Robberto, Massimo</a></td>',
#  'Duval, Julia</a></td>',
#  'Ryan, Russell</a></td>',
#  'Sankrit, Ravi</a></td>',
#  'Sargent, Beth</a></td>',
#  'Sembach, Kenneth</a></td>',
#  'Sloan, Gregory</a></td>',
#  'Smith, Linda</a></td>',
#  'Soderblom, David</a></td>',
#  'Sonnentrucker, Paule</a></td>',
#  'Stiavelli, Massimo</a></td>',
#  'Tumlinson, Jason</a></td>',
#  'Volk, Kevin</a></td>',
#  'White, Rick</a></td>',
#  'Williams, Robert</a></td>',
#  'Bradley, Larry</a></td>',
#  'Fleming, Scott</a></td>',
#  'Kendrew, Sarah</a></td>',
#  'Mutchler, Maximilian</a></td>',
#  'Pacifici, Camilla</a></td>',
#  'Zeidler, Peter</a></td>',
#  'Clark, Christopher</a></td>',
#  'French, David</a></td>',
#  'Decleir, Marjorie</a></td>',
#  'Kumari, Nimisha</a></td>',
#  'Revalski, Mitchell</a></td>',
#  'Watkins, Laura</a></td>',
#  'Hamanowicz, Aleksandra</a></td>',
#  'Gezari, Suvi</a></td>',
#  'Rickman, Emily</a></td>',
#  'Mehdipour, Missagh</a></td>',
#  'Nikolov, Nikolay</a></td>',
#  'Manjavacas, Elena</a></td>',
#  'Indriolo, Nick</a></td>',
#  'Mingozzi, Matilde</a></td>',
#  'Hernandez, Svea</a></td>',
#  'Fischer, Travis</a></td>',
#  'Pegues, Jamila</a></td>',
#  'Som, Debopam</a></td>',
#  'Anand, Gagandeep</a></td>',
#  'Flagey, Nicolas</a></td>',
#  'Jones, Logan</a></td>',
#  'Santos, Leonardo</a></td>',
#  'Huwe, Paul</a></td>',
#  'Beaton, Rachael</a></td>',
#  'Schlafly, Edward</a></td>',
#  'Meena, Beena</a></td>',
#  'Morris, Brett</a></td>',
#  'Siebert, Matthew</a></td>',
#  'Stark, David</a></td>',
#  'Goldman, Steve</a></td>',
#  'Miller, Lauren</a></td>',
#  'Mishra, Sapna</a></td>',
#  'Yung, Aaron</a></td>',
#  'Alam, Munazza</a></td>',
#  'Lothringer, Joshua</a></td>',
#  'Carter, Aarynn</a></td>',
#  'Stroe, Andra</a></td>',
#  'Fadda, Dario</a></td>',
#  'Smercina, Adam</a></td>',
#  'Escala, Ivanna</a></td>',
#  'Hasan, Farhanul</a></td>',
#  'Crotts, Katie</a></td>',
#  'Levy, Rebecca</a></td>',
#  'Orazio, Daniel</a></td>',
#  'Lowe, Hannah</a></td>',
#  'Soto, Christian</a></td>',
#  'Bushouse, Howard</a></td>',
#  'Sosey, Megan</a></td>']

# %%
names_1 = [re.sub(r'</a></td>', '', name1) for name1 in part_names1]

# %%
names_1
# Out:
# ['Alatalo, Katey',
#  'Aloisi, Alessandra',
#  'Anderson, Jay',
#  'Beck, Tracy',
#  'Bellini, Andrea',
#  'Boeker, Torsten',
#  'Boyer, Martha',
#  'Britt, Christopher',
#  'Brown, Robert',
#  'Calamida, Annalisa',
#  'Carlberg, Joleen',
#  'Chen, Christine',
#  'Chiaberge, Marco',
#  'Christian, Carol',
#  'Coe, Dan',
#  'Fox, Andrew',
#  'Fox, Ori',
#  'Fullerton, Alex',
#  'Gennaro, Mario',
#  'Gilbert, Karoline',
#  'Gordon, Karl',
#  'Goudfrooij, Paul',
#  'Hathi, Nimish',
#  'Henry, Alaina',
#  'Hines, Dean',
#  'Holler, Bryan',
#  'James, Bethan',
#  'Kassin, Susan',
#  'Koekemoer, Anton',
#  'Kriss, Gerard',
#  'LaMassa, Stephanie',
#  'Law, David',
#  'Lawton, Brandon',
#  'Leitherer, Claus',
#  'Levenson, Nancy',
#  'Long, Knox',
#  'Lubow, Steve',
#  'MacKenty, John',
#  'Marcucci, Emma',
#  'McCullough, Peter',
#  'McLean, Brian',
#  'Martin, Amaya',
#  'Page, James',
#  'Crespo, Alberto',
#  'Ogle, Patrick',
#  'Osten, Rachel',
#  'Peek, Joshua',
#  'Peeples, Molly',
#  'Pirzkal, Nor',
#  'Postman, Marc',
#  'Proffitt, Charles',
#  'Pueyo, Laurent',
#  'Rafelski, Marc',
#  'Rest, Armin',
#  'Robberto, Massimo',
#  'Duval, Julia',
#  'Ryan, Russell',
#  'Sankrit, Ravi',
#  'Sargent, Beth',
#  'Sembach, Kenneth',
#  'Sloan, Gregory',
#  'Smith, Linda',
#  'Soderblom, David',
#  'Sonnentrucker, Paule',
#  'Stiavelli, Massimo',
#  'Tumlinson, Jason',
#  'Volk, Kevin',
#  'White, Rick',
#  'Williams, Robert',
#  'Bradley, Larry',
#  'Fleming, Scott',
#  'Kendrew, Sarah',
#  'Mutchler, Maximilian',
#  'Pacifici, Camilla',
#  'Zeidler, Peter',
#  'Clark, Christopher',
#  'French, David',
#  'Decleir, Marjorie',
#  'Kumari, Nimisha',
#  'Revalski, Mitchell',
#  'Watkins, Laura',
#  'Hamanowicz, Aleksandra',
#  'Gezari, Suvi',
#  'Rickman, Emily',
#  'Mehdipour, Missagh',
#  'Nikolov, Nikolay',
#  'Manjavacas, Elena',
#  'Indriolo, Nick',
#  'Mingozzi, Matilde',
#  'Hernandez, Svea',
#  'Fischer, Travis',
#  'Pegues, Jamila',
#  'Som, Debopam',
#  'Anand, Gagandeep',
#  'Flagey, Nicolas',
#  'Jones, Logan',
#  'Santos, Leonardo',
#  'Huwe, Paul',
#  'Beaton, Rachael',
#  'Schlafly, Edward',
#  'Meena, Beena',
#  'Morris, Brett',
#  'Siebert, Matthew',
#  'Stark, David',
#  'Goldman, Steve',
#  'Miller, Lauren',
#  'Mishra, Sapna',
#  'Yung, Aaron',
#  'Alam, Munazza',
#  'Lothringer, Joshua',
#  'Carter, Aarynn',
#  'Stroe, Andra',
#  'Fadda, Dario',
#  'Smercina, Adam',
#  'Escala, Ivanna',
#  'Hasan, Farhanul',
#  'Crotts, Katie',
#  'Levy, Rebecca',
#  'Orazio, Daniel',
#  'Lowe, Hannah',
#  'Soto, Christian',
#  'Bushouse, Howard',
#  'Sosey, Megan']

# %% [markdown]
# List # 2

# %%
part_names2 = re.findall(r'\w+\,\s*\w+</td>', redirectory)

# %%
part_names2
# Out:
# ['Casertano, Stefano</td>',
#  'Chayer, Pierre</td>',
#  'Rosa, Gisella</td>',
#  'Flanagan, Kathy</td>',
#  'Fruchter, Andrew</td>',
#  'Gilliland, Ronald</td>',
#  'Golimowski, David</td>',
#  'Grogin, Norman</td>',
#  'Nebulae, Dust</td>',
#  'JWST, HST</td>',
#  'distributions, Ultraviolet</td>',
#  'Galaxies, dust</td>',
#  'Evolution, Calibrations</td>',
#  'Macchetto, Duccio</td>',
#  'Marin, Macarena</td>',
#  'Nelan, Ed</td>',
#  'Norman, Colin</td>',
#  'Sullivan, Brian</td>',
#  'Regan, Mike</td>',
#  'Riess, Adam</td>',
#  'Sirianni, Marco</td>',
#  'Sivaramakrishnan, Anand</td>',
#  'Soummer, Remi</td>',
#  'Stansberry, John</td>',
#  'Stockman, Peter</td>',
#  'Plate, Maurice</td>',
#  'Valenti, Jeff</td>',
#  'Whitmore, Brad</td>',
#  'Dieterich, Serge</td>',
#  'Espinoza, Nestor</td>',
#  'Rowlands, Kate</td>',
#  'Exoplanets, Instrumentation</td>',
#  'Bennet, Paul</td>',
#  'Gull, Ted</td>',
#  'Ntampaka, Michelle</td>',
#  'Pierel, Justin</td>',
#  'Petric, Andreea</td>',
#  'Schreier, Ethan</td>',
#  'Willman, Beth</td>',
#  'Murray, Claire</td>',
#  'Larson, Kirsten</td>',
#  'Lucy, Adrian</td>',
#  'Aguilar, Jonathan</td>',
#  'Avila, Roberto</td>',
#  'Burger, Matthew</td>',
#  'Cara, Mihai</td>',
#  'Conroy, Kyle</td>',
#  'Filippazzo, Joe</td>',
#  'Hami, Maryam</td>',
#  'Hargis, Jonathan</td>',
#  'Jones, Amy</td>',
#  'Marinelli, Mariarosa</td>',
#  'Monroe, TalaWanda</td>',
#  'Guerrero, Maria</td>',
#  'Rodriguez, David</td>',
#  'Ryon, Jenna</td>',
#  'Sahoo, Ananya</td>',
#  'Wahlgren, Glenn</td>',
#  'Yoon, Jinmi</td>',
#  'Jung, Intae</td>',
#  'Hoch, Kielan</td>',
#  'Evans, Christopher</td>',
#  'Nota, Antonella</td>',
#  'Sing, David</td>',
#  'Sharma, Sanjib</td>',
#  'Gressier, Amelie</td>',
#  'Bish, Hannah</td>',
#  'Hawcroft, Calum</td>',
#  'Shahbandeh, Melissa</td>',
#  'Pourcelot, Raphael</td>',
#  'Berger, Travis</td>',
#  'Bright, Stacey</td>',
#  'Nguyen, Meiji</td>',
#  'Steen, Richard</td>',
#  'Pauly, Tyler</td>',
#  'Shaw, Richard</td>',
#  'Spitzer, Isaac</td>',
#  'Swaters, Richard</td>',
#  'Teodore, Mairan</td>',
#  'Todd, Connor</td>',
#  'Hasselquist, Sten</td>',
#  'Betti, Sarah</td>',
#  'Steiger, Sarah</td>',
#  'Vanderhoof, Brittany</td>',
#  'Coulter, David</td>',
#  'Ranjan, Adarsh</td>',
#  'Rodriguez, Jimena</td>',
#  'Strampelli, Giovanni</td>',
#  'Gunasekera, Chamani</td>',
#  'Griggio, Massimo</td>',
#  'Maschmann, Daniel</td>',
#  'Bidot, Alexis</td>',
#  'DerKacy, James</td>',
#  'Gomez, Alejandro</td>',
#  'Ih, Jegug</td>',
#  'Vaught, Ryan</td>',
#  'Erba, Christiana</td>',
#  'Biny, Sebastian</td>',
#  'Brandt, Timothy</td>',
#  'Goovaerts, Ilias</td>',
#  'Madurowicz, Alexander</td>',
#  'Holmberg, Mans</td>',
#  'Espinosa, Macarena</td>',
#  'Morales, Mercedes</td>',
#  'Lotz, Jennifer</td>',
#  'Norman, Colin</td>',
#  'rst, Sarah</td>',
#  'Noirot, Gael</td>',
#  'Archives, Instrumentation</td>']

# %%
names_2 = [re.sub(r'</td>', '', name2) for name2 in part_names2]

# %%
names_2
# Out:
# ['Casertano, Stefano',
#  'Chayer, Pierre',
#  'Rosa, Gisella',
#  'Flanagan, Kathy',
#  'Fruchter, Andrew',
#  'Gilliland, Ronald',
#  'Golimowski, David',
#  'Grogin, Norman',
#  'Nebulae, Dust',
#  'JWST, HST',
#  'distributions, Ultraviolet',
#  'Galaxies, dust',
#  'Evolution, Calibrations',
#  'Macchetto, Duccio',
#  'Marin, Macarena',
#  'Nelan, Ed',
#  'Norman, Colin',
#  'Sullivan, Brian',
#  'Regan, Mike',
#  'Riess, Adam',
#  'Sirianni, Marco',
#  'Sivaramakrishnan, Anand',
#  'Soummer, Remi',
#  'Stansberry, John',
#  'Stockman, Peter',
#  'Plate, Maurice',
#  'Valenti, Jeff',
#  'Whitmore, Brad',
#  'Dieterich, Serge',
#  'Espinoza, Nestor',
#  'Rowlands, Kate',
#  'Exoplanets, Instrumentation',
#  'Bennet, Paul',
#  'Gull, Ted',
#  'Ntampaka, Michelle',
#  'Pierel, Justin',
#  'Petric, Andreea',
#  'Schreier, Ethan',
#  'Willman, Beth',
#  'Murray, Claire',
#  'Larson, Kirsten',
#  'Lucy, Adrian',
#  'Aguilar, Jonathan',
#  'Avila, Roberto',
#  'Burger, Matthew',
#  'Cara, Mihai',
#  'Conroy, Kyle',
#  'Filippazzo, Joe',
#  'Hami, Maryam',
#  'Hargis, Jonathan',
#  'Jones, Amy',
#  'Marinelli, Mariarosa',
#  'Monroe, TalaWanda',
#  'Guerrero, Maria',
#  'Rodriguez, David',
#  'Ryon, Jenna',
#  'Sahoo, Ananya',
#  'Wahlgren, Glenn',
#  'Yoon, Jinmi',
#  'Jung, Intae',
#  'Hoch, Kielan',
#  'Evans, Christopher',
#  'Nota, Antonella',
#  'Sing, David',
#  'Sharma, Sanjib',
#  'Gressier, Amelie',
#  'Bish, Hannah',
#  'Hawcroft, Calum',
#  'Shahbandeh, Melissa',
#  'Pourcelot, Raphael',
#  'Berger, Travis',
#  'Bright, Stacey',
#  'Nguyen, Meiji',
#  'Steen, Richard',
#  'Pauly, Tyler',
#  'Shaw, Richard',
#  'Spitzer, Isaac',
#  'Swaters, Richard',
#  'Teodore, Mairan',
#  'Todd, Connor',
#  'Hasselquist, Sten',
#  'Betti, Sarah',
#  'Steiger, Sarah',
#  'Vanderhoof, Brittany',
#  'Coulter, David',
#  'Ranjan, Adarsh',
#  'Rodriguez, Jimena',
#  'Strampelli, Giovanni',
#  'Gunasekera, Chamani',
#  'Griggio, Massimo',
#  'Maschmann, Daniel',
#  'Bidot, Alexis',
#  'DerKacy, James',
#  'Gomez, Alejandro',
#  'Ih, Jegug',
#  'Vaught, Ryan',
#  'Erba, Christiana',
#  'Biny, Sebastian',
#  'Brandt, Timothy',
#  'Goovaerts, Ilias',
#  'Madurowicz, Alexander',
#  'Holmberg, Mans',
#  'Espinosa, Macarena',
#  'Morales, Mercedes',
#  'Lotz, Jennifer',
#  'Norman, Colin',
#  'rst, Sarah',
#  'Noirot, Gael',
#  'Archives, Instrumentation']

# %% [markdown]
# List # 3

# %%
part_names3 = re.findall(r'\w+\,\s*\w+\s*\w+\.</a></td>', redirectory)

# %% [markdown]
# part_names3

# %%
names_3 = [re.sub(r'</a></td>', '', name3) for name3 in part_names3]

# %%
names_3
# Out:
# ['Bohlin, Ralph C.',
#  'Brown, Thomas M.',
#  'Debes, John H.',
#  'Ferguson, Henry C.',
#  'Friedman, Scott D.',
#  'Green, Joel D.',
#  'Hauser, Michael G.',
#  'Perrin, Marshall D.',
#  'Reid, Neill I.',
#  'Sahu, Kailash C.',
#  'Tollerud, Erik J.',
#  'Marel, Roeland P.',
#  'Welty, Daniel E.',
#  'Blair, William P.',
#  'Girard, Julien H.',
#  'Mullally, Susan E.',
#  'Lucas, Ray A.',
#  'Wu, John F.',
#  'Por, Emiel H.',
#  'Tea, Mason V.',
#  'Johnson, Christian I.']

# %% [markdown]
# merge 3 list

# %%
names= names_1 + names_2 + names_3
names
# Out:
# ['Alatalo, Katey',
#  'Aloisi, Alessandra',
#  'Anderson, Jay',
#  'Beck, Tracy',
#  'Bellini, Andrea',
#  'Boeker, Torsten',
#  'Boyer, Martha',
#  'Britt, Christopher',
#  'Brown, Robert',
#  'Calamida, Annalisa',
#  'Carlberg, Joleen',
#  'Chen, Christine',
#  'Chiaberge, Marco',
#  'Christian, Carol',
#  'Coe, Dan',
#  'Fox, Andrew',
#  'Fox, Ori',
#  'Fullerton, Alex',
#  'Gennaro, Mario',
#  'Gilbert, Karoline',
#  'Gordon, Karl',
#  'Goudfrooij, Paul',
#  'Hathi, Nimish',
#  'Henry, Alaina',
#  'Hines, Dean',
#  'Holler, Bryan',
#  'James, Bethan',
#  'Kassin, Susan',
#  'Koekemoer, Anton',
#  'Kriss, Gerard',
#  'LaMassa, Stephanie',
#  'Law, David',
#  'Lawton, Brandon',
#  'Leitherer, Claus',
#  'Levenson, Nancy',
#  'Long, Knox',
#  'Lubow, Steve',
#  'MacKenty, John',
#  'Marcucci, Emma',
#  'McCullough, Peter',
#  'McLean, Brian',
#  'Martin, Amaya',
#  'Page, James',
#  'Crespo, Alberto',
#  'Ogle, Patrick',
#  'Osten, Rachel',
#  'Peek, Joshua',
#  'Peeples, Molly',
#  'Pirzkal, Nor',
#  'Postman, Marc',
#  'Proffitt, Charles',
#  'Pueyo, Laurent',
#  'Rafelski, Marc',
#  'Rest, Armin',
#  'Robberto, Massimo',
#  'Duval, Julia',
#  'Ryan, Russell',
#  'Sankrit, Ravi',
#  'Sargent, Beth',
#  'Sembach, Kenneth',
#  'Sloan, Gregory',
#  'Smith, Linda',
#  'Soderblom, David',
#  'Sonnentrucker, Paule',
#  'Stiavelli, Massimo',
#  'Tumlinson, Jason',
#  'Volk, Kevin',
#  'White, Rick',
#  'Williams, Robert',
#  'Bradley, Larry',
#  'Fleming, Scott',
#  'Kendrew, Sarah',
#  'Mutchler, Maximilian',
#  'Pacifici, Camilla',
#  'Zeidler, Peter',
#  'Clark, Christopher',
#  'French, David',
#  'Decleir, Marjorie',
#  'Kumari, Nimisha',
#  'Revalski, Mitchell',
#  'Watkins, Laura',
#  'Hamanowicz, Aleksandra',
#  'Gezari, Suvi',
#  'Rickman, Emily',
#  'Mehdipour, Missagh',
#  'Nikolov, Nikolay',
#  'Manjavacas, Elena',
#  'Indriolo, Nick',
#  'Mingozzi, Matilde',
#  'Hernandez, Svea',
#  'Fischer, Travis',
#  'Pegues, Jamila',
#  'Som, Debopam',
#  'Anand, Gagandeep',
#  'Flagey, Nicolas',
#  'Jones, Logan',
#  'Santos, Leonardo',
#  'Huwe, Paul',
#  'Beaton, Rachael',
#  'Schlafly, Edward',
#  'Meena, Beena',
#  'Morris, Brett',
#  'Siebert, Matthew',
#  'Stark, David',
#  'Goldman, Steve',
#  'Miller, Lauren',
#  'Mishra, Sapna',
#  'Yung, Aaron',
#  'Alam, Munazza',
#  'Lothringer, Joshua',
#  'Carter, Aarynn',
#  'Stroe, Andra',
#  'Fadda, Dario',
#  'Smercina, Adam',
#  'Escala, Ivanna',
#  'Hasan, Farhanul',
#  'Crotts, Katie',
#  'Levy, Rebecca',
#  'Orazio, Daniel',
#  'Lowe, Hannah',
#  'Soto, Christian',
#  'Bushouse, Howard',
#  'Sosey, Megan',
#  'Casertano, Stefano',
#  'Chayer, Pierre',
#  'Rosa, Gisella',
#  'Flanagan, Kathy',
#  'Fruchter, Andrew',
#  'Gilliland, Ronald',
#  'Golimowski, David',
#  'Grogin, Norman',
#  'Nebulae, Dust',
#  'JWST, HST',
#  'distributions, Ultraviolet',
#  'Galaxies, dust',
#  'Evolution, Calibrations',
#  'Macchetto, Duccio',
#  'Marin, Macarena',
#  'Nelan, Ed',
#  'Norman, Colin',
#  'Sullivan, Brian',
#  'Regan, Mike',
#  'Riess, Adam',
#  'Sirianni, Marco',
#  'Sivaramakrishnan, Anand',
#  'Soummer, Remi',
#  'Stansberry, John',
#  'Stockman, Peter',
#  'Plate, Maurice',
#  'Valenti, Jeff',
#  'Whitmore, Brad',
#  'Dieterich, Serge',
#  'Espinoza, Nestor',
#  'Rowlands, Kate',
#  'Exoplanets, Instrumentation',
#  'Bennet, Paul',
#  'Gull, Ted',
#  'Ntampaka, Michelle',
#  'Pierel, Justin',
#  'Petric, Andreea',
#  'Schreier, Ethan',
#  'Willman, Beth',
#  'Murray, Claire',
#  'Larson, Kirsten',
#  'Lucy, Adrian',
#  'Aguilar, Jonathan',
#  'Avila, Roberto',
#  'Burger, Matthew',
#  'Cara, Mihai',
#  'Conroy, Kyle',
#  'Filippazzo, Joe',
#  'Hami, Maryam',
#  'Hargis, Jonathan',
#  'Jones, Amy',
#  'Marinelli, Mariarosa',
#  'Monroe, TalaWanda',
#  'Guerrero, Maria',
#  'Rodriguez, David',
#  'Ryon, Jenna',
#  'Sahoo, Ananya',
#  'Wahlgren, Glenn',
#  'Yoon, Jinmi',
#  'Jung, Intae',
#  'Hoch, Kielan',
#  'Evans, Christopher',
#  'Nota, Antonella',
#  'Sing, David',
#  'Sharma, Sanjib',
#  'Gressier, Amelie',
#  'Bish, Hannah',
#  'Hawcroft, Calum',
#  'Shahbandeh, Melissa',
#  'Pourcelot, Raphael',
#  'Berger, Travis',
#  'Bright, Stacey',
#  'Nguyen, Meiji',
#  'Steen, Richard',
#  'Pauly, Tyler',
#  'Shaw, Richard',
#  'Spitzer, Isaac',
#  'Swaters, Richard',
#  'Teodore, Mairan',
#  'Todd, Connor',
#  'Hasselquist, Sten',
#  'Betti, Sarah',
#  'Steiger, Sarah',
#  'Vanderhoof, Brittany',
#  'Coulter, David',
#  'Ranjan, Adarsh',
#  'Rodriguez, Jimena',
#  'Strampelli, Giovanni',
#  'Gunasekera, Chamani',
#  'Griggio, Massimo',
#  'Maschmann, Daniel',
#  'Bidot, Alexis',
#  'DerKacy, James',
#  'Gomez, Alejandro',
#  'Ih, Jegug',
#  'Vaught, Ryan',
#  'Erba, Christiana',
#  'Biny, Sebastian',
#  'Brandt, Timothy',
#  'Goovaerts, Ilias',
#  'Madurowicz, Alexander',
#  'Holmberg, Mans',
#  'Espinosa, Macarena',
#  'Morales, Mercedes',
#  'Lotz, Jennifer',
#  'Norman, Colin',
#  'rst, Sarah',
#  'Noirot, Gael',
#  'Archives, Instrumentation',
#  'Bohlin, Ralph C.',
#  'Brown, Thomas M.',
#  'Debes, John H.',
#  'Ferguson, Henry C.',
#  'Friedman, Scott D.',
#  'Green, Joel D.',
#  'Hauser, Michael G.',
#  'Perrin, Marshall D.',
#  'Reid, Neill I.',
#  'Sahu, Kailash C.',
#  'Tollerud, Erik J.',
#  'Marel, Roeland P.',
#  'Welty, Daniel E.',
#  'Blair, William P.',
#  'Girard, Julien H.',
#  'Mullally, Susan E.',
#  'Lucas, Ray A.',
#  'Wu, John F.',
#  'Por, Emiel H.',
#  'Tea, Mason V.',
#  'Johnson, Christian I.']

# %%
print("Total Names = " + str(len(names)))
# Out:
# Total Names = 253

# %% [markdown]
# **2.3 Match each name with its corresponding email**

# %% [markdown]
# create the username from the name to enable maching with the email later

# %%
# {name[0]}{last} -> This expression combines the first letter of the first name with the last name into a single string

match = []

for n in names:
    last, name = n.split(',')
    last = last.strip().lower()
    name = name.strip().lower()
    
    for m in real_mail:
        username = m.split('@')[0]
        if username == f"{name[0]}{last}":
            match.append(f"{last}, {name}; {m}")
            break

# %%
print(match)
# Out:
# ['alatalo, katey; kalatalo@stsci.com', 'beck, tracy; tbeck@stsci.com', 'boyer, martha; mboyer@stsci.com', 'britt, christopher; cbritt@stsci.com', 'carlberg, joleen; jcarlberg@stsci.com', 'chen, christine; cchen@stsci.com', 'coe, dan; dcoe@stsci.com', 'fox, andrew; afox@stsci.com', 'fox, ori; ofox@stsci.com', 'gilbert, karoline; kgilbert@stsci.com', 'gordon, karl; kgordon@stsci.com', 'hathi, nimish; nhathi@stsci.com', 'henry, alaina; ahenry@stsci.com', 'holler, bryan; bholler@stsci.com', 'james, bethan; bjames@stsci.com', 'lamassa, stephanie; slamassa@stsci.com', 'law, david; dlaw@stsci.com', 'levenson, nancy; nlevenson@stsci.com', 'marcucci, emma; emarcucci@stsci.com', 'ogle, patrick; pogle@stsci.com', 'pirzkal, nor; npirzkal@stsci.com', 'rafelski, marc; mrafelski@stsci.com', 'rest, armin; arest@stsci.com', 'ryan, russell; rryan@stsci.com', 'sankrit, ravi; rsankrit@stsci.com', 'smith, linda; lsmith@stsci.com', 'bradley, larry; lbradley@stsci.com', 'kendrew, sarah; skendrew@stsci.com', 'pacifici, camilla; cpacifici@stsci.com', 'clark, christopher; cclark@stsci.com', 'french, david; dfrench@stsci.com', 'decleir, marjorie; mdecleir@stsci.com', 'revalski, mitchell; mrevalski@stsci.com', 'watkins, laura; lwatkins@stsci.com', 'mehdipour, missagh; mmehdipour@stsci.com', 'nikolov, nikolay; nnikolov@stsci.com', 'manjavacas, elena; emanjavacas@stsci.com', 'indriolo, nick; nindriolo@stsci.com', 'mingozzi, matilde; mmingozzi@stsci.com', 'hernandez, svea; shernandez@stsci.com', 'fischer, travis; tfischer@stsci.com', 'pegues, jamila; jpegues@stsci.com', 'som, debopam; dsom@stsci.com', 'anand, gagandeep; ganand@stsci.com', 'flagey, nicolas; nflagey@stsci.com', 'huwe, paul; phuwe@stsci.com', 'beaton, rachael; rbeaton@stsci.com', 'schlafly, edward; eschlafly@stsci.com', 'meena, beena; bmeena@stsci.com', 'siebert, matthew; msiebert@stsci.com', 'stark, david; dstark@stsci.com', 'goldman, steve; sgoldman@stsci.com', 'miller, lauren; lmiller@stsci.com', 'alam, munazza; malam@stsci.com', 'lothringer, joshua; jlothringer@stsci.com', 'stroe, andra; astroe@stsci.com', 'fadda, dario; dfadda@stsci.com', 'smercina, adam; asmercina@stsci.com', 'escala, ivanna; iescala@stsci.com', 'hasan, farhanul; fhasan@stsci.com', 'crotts, katie; kcrotts@stsci.com', 'levy, rebecca; rlevy@stsci.com', 'orazio, daniel; dorazio@stsci.com', 'soto, christian; csoto@stsci.com', 'bushouse, howard; hbushouse@stsci.com', 'regan, mike; mregan@stsci.com', 'riess, adam; ariess@stsci.com', 'plate, maurice; mplate@stsci.com', 'dieterich, serge; sdieterich@stsci.com', 'espinoza, nestor; nespinoza@stsci.com', 'rowlands, kate; krowlands@stsci.com', 'bennet, paul; pbennet@stsci.com', 'gull, ted; tgull@stsci.com', 'ntampaka, michelle; mntampaka@stsci.com', 'pierel, justin; jpierel@stsci.com', 'petric, andreea; apetric@stsci.com', 'lucy, adrian; alucy@stsci.com', 'aguilar, jonathan; jaguilar@stsci.com', 'burger, matthew; mburger@stsci.com', 'cara, mihai; mcara@stsci.com', 'conroy, kyle; kconroy@stsci.com', 'filippazzo, joe; jfilippazzo@stsci.com', 'hami, maryam; mhami@stsci.com', 'hargis, jonathan; jhargis@stsci.com', 'marinelli, mariarosa; mmarinelli@stsci.com', 'monroe, talawanda; tmonroe@stsci.com', 'rodriguez, david; drodriguez@stsci.com', 'sahoo, ananya; asahoo@stsci.com', 'wahlgren, glenn; gwahlgren@stsci.com', 'yoon, jinmi; jyoon@stsci.com', 'jung, intae; ijung@stsci.com', 'hoch, kielan; khoch@stsci.com', 'sharma, sanjib; ssharma@stsci.com', 'gressier, amelie; agressier@stsci.com', 'bish, hannah; hbish@stsci.com', 'hawcroft, calum; chawcroft@stsci.com', 'shahbandeh, melissa; mshahbandeh@stsci.com', 'pourcelot, raphael; rpourcelot@stsci.com', 'berger, travis; tberger@stsci.com', 'nguyen, meiji; mnguyen@stsci.com', 'pauly, tyler; tpauly@stsci.com', 'spitzer, isaac; ispitzer@stsci.com', 'swaters, richard; rswaters@stsci.com', 'teodore, mairan; mteodore@stsci.com', 'todd, connor; ctodd@stsci.com', 'hasselquist, sten; shasselquist@stsci.com', 'betti, sarah; sbetti@stsci.com', 'steiger, sa ...

# %%
len(match)
# Out:
# 137

# %%
match2 = []

for n in names:
    last, name = n.split(',')
    last = last.strip().lower()
    name = name.strip().lower()
    
    for m in real_mail:
        username2 = m.split('@')[0]
        if username2 == f"{last}":
            match2.append(f"{last}, {name}; {m}")
            break

# %%
print(match2)
# Out:
# ['aloisi, alessandra; aloisi@stsci.com', 'bellini, andrea; bellini@stsci.com', 'boeker, torsten; boeker@stsci.com', 'calamida, annalisa; calamida@stsci.com', 'fullerton, alex; fullerton@stsci.com', 'gennaro, mario; gennaro@stsci.com', 'hines, dean; hines@stsci.com', 'kassin, susan; kassin@stsci.com', 'koekemoer, anton; koekemoer@stsci.com', 'lawton, brandon; lawton@stsci.com', 'leitherer, claus; leitherer@stsci.com', 'long, knox; long@stsci.com', 'lubow, steve; lubow@stsci.com', 'mackenty, john; mackenty@stsci.com', 'mclean, brian; mclean@stsci.com', 'osten, rachel; osten@stsci.com', 'postman, marc; postman@stsci.com', 'proffitt, charles; proffitt@stsci.com', 'pueyo, laurent; pueyo@stsci.com', 'robberto, massimo; robberto@stsci.com', 'duval, julia; duval@stsci.com', 'sargent, beth; sargent@stsci.com', 'sembach, kenneth; sembach@stsci.com', 'tumlinson, jason; tumlinson@stsci.com', 'volk, kevin; volk@stsci.com', 'fleming, scott; fleming@stsci.com', 'mutchler, maximilian; mutchler@stsci.com', 'zeidler, peter; zeidler@stsci.com', 'kumari, nimisha; kumari@stsci.com', 'anand, gagandeep; anand@stsci.com', 'yung, aaron; yung@stsci.com', 'sosey, megan; sosey@stsci.com', 'chayer, pierre; chayer@stsci.com', 'flanagan, kathy; flanagan@stsci.com', 'fruchter, andrew; fruchter@stsci.com', 'nelan, ed; nelan@stsci.com', 'norman, colin; norman@stsci.com', 'sirianni, marco; sirianni@stsci.com', 'soummer, remi; soummer@stsci.com', 'valenti, jeff; valenti@stsci.com', 'whitmore, brad; whitmore@stsci.com', 'avila, roberto; avila@stsci.com', 'ryon, jenna; ryon@stsci.com', 'bright, stacey; bright@stsci.com', 'shaw, richard; shaw@stsci.com', 'lotz, jennifer; lotz@stsci.com', 'norman, colin; norman@stsci.com', 'bohlin, ralph c.; bohlin@stsci.com', 'debes, john h.; debes@stsci.com', 'ferguson, henry c.; ferguson@stsci.com', 'friedman, scott d.; friedman@stsci.com', 'marel, roeland p.; marel@stsci.com', 'lucas, ray a.; lucas@stsci.com']

# %%
len(match2)
# Out:
# 53

# %%
match3 = []

for n in names:
    last, name = n.split(',')
    last = last.strip().lower()
    name = name.strip().lower()
    
    for m in real_mail:
        username3 = m.split('@')[0]
        if username3 == f"{name}":
            match3.append(f"{last}, {name}; {m}")

# %%
print(match3)
# Out:
# ['martin, amaya; amaya@stsci.com', 'peeples, molly; molly@stsci.com', 'casertano, stefano; stefano@stsci.com', 'grogin, norman; norman@stsci.com', 'grogin, norman; norman@stsci.com', 'macchetto, duccio; duccio@stsci.com', 'sivaramakrishnan, anand; anand@stsci.com']

# %%
len(match3)
# Out:
# 7

# %%
match4 = []

for n in names:
    last, name = n.split(',')
    last = last.strip().lower()
    name = name.strip().lower()
    
    for m in real_mail:
        username4 = m.split('@')[0]
        if username4 == f"{name[:3]}{last[:5]}":
            match4.append(f"{last}, {name}; {m}")
            break

# %%
print(match4)
# Out:
# ['anderson, jay; jayander@stsci.com']

# %%
mail_name= match + match2 + match3

# %%
len(mail_name)
# Out:
# 197

# %% [markdown]
# **2.2 Create a list with names**

# %%
match1 = re.search(r'<a[^>]*>([^<]+)</a></td>', redirectory)
#result1 = match1.group(1) if match1 else None
print(match1.group(1))
# Out:
# Alatalo, Katey

# %%
match_name = re.search(r'<td[^>]*style="[^"]*width:\s*15%;[^"]*"[^>]*>\s*<a[^>]*>([^<]+)</a></td>', redirectory)
match_mail= re.search(r'<td[^>]*>([^<]+)<br\s*/?>', redirectory)

print(
    f"{match_name.group(1) if match_name else ''};{match_mail.group(1) if match_mail else ''}"
)
# Out:
# Alatalo, Katey;kalatalo

# %%
# Find all name matches
names = re.findall(r'<td[^>]*style="[^"]*width:\s*15%;[^"]*"[^>]*>\s*<a[^>]*>([^<]+)</a>', redirectory)

# Find all email matches
emails = re.findall(r'<td[^>]*>([^<]+)<br\s*/?>', redirectory)

# Combine name-email pairs
for name, email in zip(names, emails):
    print(f"{name};{email}")
# Out:
# Alatalo, Katey;kalatalo
# Aloisi, Alessandra;aloisi
# Anderson, Jay;jayander
# Beck, Tracy;tbeck
# Bellini, Andrea;bellini
# Boeker, Torsten;boeker
# Bohlin, Ralph C.;bohlin
# Boyer, Martha;mboyer
# Britt, Christopher;tbrown
# Brown, Robert;calamida
# Brown, Thomas M.;jcarlberg
# Calamida, Annalisa;stefano
# Carlberg, Joleen;chayer
# Chen, Christine;cchen
# Chiaberge, Marco;marcoc
# Christian, Carol;carolc
# Coe, Dan;dcoe
# Debes, John H.;gderosa
# Dixon, William Van Dyke;debes
# Ferguson, Henry C.;dixon
# Fox, Andrew;ferguson
# Fox, Ori;flanagan
# Friedman, Scott D.;afox
# Fullerton, Alex;ofox
# Gennaro, Mario;friedman
# Gilbert, Karoline;fruchter
# Gordon, Karl;fullerton
# Goudfrooij, Paul;gennaro
# Green, Joel D.;kgilbert
# Hathi, Nimish;golim
# Hauser, Michael G.;kgordon
# Henry, Alaina;goudfroo
# Hines, Dean;jgreen
# Holler, Bryan;nagrogin
# James, Bethan;nhathi
# Kassin, Susan;ahenry
# Keyes, Charles Tony;hines
# Koekemoer, Anton;bholler
# Kriss, Gerard;bjames
# LaMassa, Stephanie;kassin
# Law, David;keyes
# Lawton, Brandon;koekemoer
# Leitherer, Claus;gak
# Levenson, Nancy;slamassa
# Long, Knox;dlaw
# Lubow, Steve;lawton
# MacKenty, John;leitherer
# Marcucci, Emma;nlevenson
# McCullough, Peter;long
# McLean, Brian;lubow
# Moro-Martin, Amaya;mackenty
# Muzerolle Page, James;duccio
# Noriega-Crespo, Alberto;emarcucci
# Ogle, Patrick;maca
# Osten, Rachel;pmcc
# Peek, Joshua;mclean
# Peeples, Molly;amaya
# Perrin, Marshall D.;muzerol
# Pirzkal, Nor;nelan
# Postman, Marc;anoriega
# Proffitt, Charles;norman
# Pueyo, Laurent;pogle
# Rafelski, Marc;osten
# Reid, Neill I.;bosullivan
# Rest, Armin;jegpeek
# Robberto, Massimo;molly
# Roman-Duval, Julia;mperrin
# Ryan, Russell;npirzkal
# Sahu, Kailash C.;postman
# Sankrit, Ravi;proffitt
# Sargent, Beth;pueyo
# Sembach, Kenneth;mrafelski
# Sloan, Gregory;mregan
# Smith, Linda;inr
# Soderblom, David;arest
# Sohn, Sangmo Tony;ariess
# Sonnentrucker, Paule;robberto
# Stiavelli, Massimo;duval
# Strolger, Louis-Gregory;rryan
# Tollerud, Erik J.;ksahu
# Tumlinson, Jason;rsankrit
# van der Marel, Roeland P.;sargent
# Volk, Kevin;sembach
# Welty, Daniel E.;sirianni
# White, Rick;anand
# Williams, Robert;gcsloan
# Blair, William P.;lsmith
# Bradley, Larry;drs
# Fleming, Scott;tsohn
# Girard, Julien H.;sonnentr
# Kendrew, Sarah;soummer
# Mullally, Susan E.;jstans
# Mutchler, Maximilian;mstiavel
# Pacifici, Camilla;strolger
# Zeidler, Peter;mplate
# Lucas, Ray A.;etollerud
# Clark, Christopher;tumlinson
# French, David;valenti
# Decleir, Marjorie;marel
# Kumari, Nimisha;volk
# Revalski, Mitchell;dwelty
# Watkins, Laura;rlw
# Wu, John F.;whitmore
# Hamanowicz, Aleksandra;wblair
# Gezari, Suvi;lbradley
# Rickman, Emily;fleming
# Mehdipour, Missagh;jgirard
# Nikolov, Nikolay;skendrew
# Por, Emiel H.;smullally
# Manjavacas, Elena;mutchler
# Indriolo, Nick;sparks
# Mingozzi, Matilde;cpacifici
# Hernandez, Svea;zeidler
# Fischer, Travis;lucas
# Pegues, Jamila;cclark
# Som, Debopam;mdecleir
# Anand, Gagandeep;sdieterich
# Flagey, Nicolas;nespinoza
# Jones, Logan;kumari
# Tea, Mason V.;mrevalski
# Dos Santos, Leonardo;krowlands
# Johnson, Christian I.;lwatkins
# Huwe, Paul;mmehdipour
# Beaton, Rachael;nindriolo
# Schlafly, Edward;pbennet
# Meena, Beena;tgull
# Morris, Brett;ESA/AURA
# Siebert, Matthew;mmingozzi
# Stark, David;mntampaka
# Goldman, Steve;jpierel
# Miller, Lauren;apetric
# Lee, Janice C.&nbsp;;shernandez
# Mishra, Sapna;tfischer
# Yung, Aaron;jpegues
# Alam, Munazza;cmurray1
# Lothringer, Joshua;kilarson
# Carter, Aarynn;dsom
# Stroe, Andra;ganand
# Wong, Ian;nflagey
# Fadda, Dario;lojones
# Smercina, Adam;mtea
# Escala, Ivanna;ldsantos
# Hasan, Farhanul;cjohnson1
# Crotts, Katie;alucy
# Levy, Rebecca;phuwe
# McQuinn, Kristen B. Wingfield;jaguilar
# D&#39;Orazio, Daniel;avila
# Diamond-Lowe, Hannah;mburger
# Soto, Christian;mcara
# Bushouse, Howard;kconroy
# Sosey, Megan;jfilippazzo

# %%
len(names)
# Out:
# 151

# %%
# Pattern to capture the name

name_re = re.compile(
    r'<td[^>]*style="[^"]*width:\s*15%;[^"]*"[^>]*>\s*(?:<a[^>]*>)?([^<]+)(?:</a>)?\s*</td>',
    re.IGNORECASE
)

# Pattern to capture the email, whether in <td> or in <p>

mail_re = re.compile(
    r'<(?:td[^>]*|p[^>]*)>\s*([^<]+)\s*<br\s*/?>',
    re.IGNORECASE
)

# Prepare the list
results = []

# Split into rows and process each one
rows = re.findall(r'<tr.*?>.*?</tr>', redirectory, flags=re.DOTALL|re.IGNORECASE)
for html_row in rows:
    nm = name_re.search(html_row)
    ml = mail_re.search(html_row)
    name = nm.group(1) if nm else ''
    mail = ml.group(1) if ml else ''
    email = f"{mail}@gmail.com" if mail else ''
    

    #results.append(f"{name};{mail}@stsci.com")
    results.append(f"{name};{email}")

# %%
results
# Out:
# [';',
#  'Alatalo, Katey;kalatalo@gmail.com',
#  'Aloisi, Alessandra;aloisi@gmail.com',
#  'Anderson, Jay;jayander@gmail.com',
#  'Beck, Tracy;tbeck@gmail.com',
#  'Bellini, Andrea;bellini@gmail.com',
#  'Boeker, Torsten;boeker@gmail.com',
#  'Bohlin, Ralph C.;bohlin@gmail.com',
#  'Bond, Howard E.;',
#  'Boyer, Martha;mboyer@gmail.com',
#  'Britt, Christopher;cbritt@gmail.com',
#  'Brown, Robert;',
#  'Brown, Thomas M.;tbrown@gmail.com',
#  'Calamida, Annalisa;calamida@gmail.com',
#  'Carlberg, Joleen;jcarlberg@gmail.com',
#  'Casertano, Stefano;stefano@gmail.com',
#  'Chayer, Pierre;chayer@gmail.com',
#  'Chen, Christine;cchen@gmail.com',
#  'Chiaberge, Marco;marcoc@gmail.com',
#  'Christian, Carol;carolc@gmail.com',
#  'Coe, Dan;dcoe@gmail.com',
#  'de Rosa, Gisella;gderosa@gmail.com',
#  'Debes, John H.;debes@gmail.com',
#  'Dixon, William Van Dyke;dixon@gmail.com',
#  'Ferguson, Henry C.;ferguson@gmail.com',
#  'Flanagan, Kathy;flanagan@gmail.com',
#  'Fox, Andrew;afox@gmail.com',
#  'Fox, Ori;ofox@gmail.com',
#  'Friedman, Scott D.;friedman@gmail.com',
#  'Fruchter, Andrew;fruchter@gmail.com',
#  'Fullerton, Alex;fullerton@gmail.com',
#  'Gennaro, Mario;gennaro@gmail.com',
#  'Gilbert, Karoline;kgilbert@gmail.com',
#  'Gilliland, Ronald;',
#  'Golimowski, David;golim@gmail.com',
#  'Gordon, Karl;kgordon@gmail.com',
#  'Goudfrooij, Paul;goudfroo@gmail.com',
#  'Green, Joel D.;jgreen@gmail.com',
#  'Grogin, Norman;nagrogin@gmail.com',
#  'Hathi, Nimish;nhathi@gmail.com',
#  'Hauser, Michael G.;',
#  'Henry, Alaina;ahenry@gmail.com',
#  'Hines, Dean;hines@gmail.com',
#  'Holler, Bryan;bholler@gmail.com',
#  'James, Bethan;bjames@gmail.com',
#  'Kassin, Susan;kassin@gmail.com',
#  'Keyes, Charles Tony;keyes@gmail.com',
#  'Koekemoer, Anton;koekemoer@gmail.com',
#  'Kriss, Gerard;gak@gmail.com',
#  'LaMassa, Stephanie;slamassa@gmail.com',
#  'Law, David;dlaw@gmail.com',
#  'Lawton, Brandon;lawton@gmail.com',
#  'Leitherer, Claus;leitherer@gmail.com',
#  'Levenson, Nancy;nlevenson@gmail.com',
#  'Long, Knox;long@gmail.com',
#  'Lubow, Steve;lubow@gmail.com',
#  'MacKenty, John;mackenty@gmail.com',
#  'Macchetto, Duccio;duccio@gmail.com',
#  'Marcucci, Emma;emarcucci@gmail.com',
#  'Garcia Marin, Macarena;maca@gmail.com',
#  'McCullough, Peter;pmcc@gmail.com',
#  'McLean, Brian;mclean@gmail.com',
#  'Moro-Martin, Amaya;amaya@gmail.com',
#  'Muzerolle Page, James;muzerol@gmail.com',
#  'Nelan, Ed;nelan@gmail.com',
#  'Noriega-Crespo, Alberto;anoriega@gmail.com',
#  'Norman, Colin;norman@gmail.com',
#  'Ogle, Patrick;pogle@gmail.com',
#  'Osten, Rachel;osten@gmail.com',
#  'O&#39;Sullivan, Brian;bosullivan@gmail.com',
#  'Peek, Joshua;jegpeek@gmail.com',
#  'Peeples, Molly;molly@gmail.com',
#  'Perrin, Marshall D.;mperrin@gmail.com',
#  'Pirzkal, Nor;npirzkal@gmail.com',
#  'Postman, Marc;postman@gmail.com',
#  'Proffitt, Charles;proffitt@gmail.com',
#  'Pueyo, Laurent;pueyo@gmail.com',
#  'Rafelski, Marc;mrafelski@gmail.com',
#  'Regan, Mike;mregan@gmail.com',
#  'Reid, Neill I.;inr@gmail.com',
#  'Rest, Armin;arest@gmail.com',
#  'Riess, Adam;ariess@gmail.com',
#  'Robberto, Massimo;robberto@gmail.com',
#  'Roman-Duval, Julia;duval@gmail.com',
#  'Ryan, Russell;rryan@gmail.com',
#  'Sahu, Kailash C.;ksahu@gmail.com',
#  'Sankrit, Ravi;rsankrit@gmail.com',
#  'Sargent, Beth;sargent@gmail.com',
#  'Sembach, Kenneth;sembach@gmail.com',
#  'Sirianni, Marco;sirianni@gmail.com',
#  'Sivaramakrishnan, Anand;anand@gmail.com',
#  'Sloan, Gregory;gcsloan@gmail.com',
#  'Smith, Linda;lsmith@gmail.com',
#  'Soderblom, David;drs@gmail.com',
#  'Sohn, Sangmo Tony;tsohn@gmail.com',
#  'Sonnentrucker, Paule;sonnentr@gmail.com',
#  'Soummer, Remi;soummer@gmail.com',
#  'Stansberry, John;jstans@gmail.com',
#  'Stiavelli, Massimo;mstiavel@gmail.com',
#  'Stockman, Peter;',
#  'Strolger, Louis-Gregory;strolger@gmail.com',
#  'Te Plate, Maurice;mplate@gmail.com',
#  'Tollerud, Erik J.;etollerud@gmail.com',
#  'Tumlinson, Jason;tumlinson@gmail.com',
#  'Valenti, Jeff;valenti@gmail.com',
#  'van der Marel, Roeland P.;marel@gmail.com',
#  'Volk, Kevin;volk@gmail.com',
#  'Welty, Daniel E.;dwelty@gmail.com',
#  'White, Rick;rlw@gmail.com',
#  'Whitmore, Brad;whitmore@gmail.com',
#  'Williams, Robert;',
#  'Blair, William P.;wblair@gmail.com',
#  'Bradley, Larry;lbradley@gmail.com',
#  'Fleming, Scott;fleming@gmail.com',
#  'Girard, Julien H.;jgirard@gmail.com',
#  'Kendrew, Sarah;skendrew@gmail.com',
#  'Mullally, Susan E.;smullally@gmail.com',
#  'Mutchler, Maximilian;mutchler@gmail.com',
#  'Sparks, B.;sparks@gmail.com',
#  'Pacifici, Camilla;cpacifici@gmail.com',
#  'Zeidler, Peter;zeidler@gmail.com',
#  'Lucas, Ray A.;lucas@gmail.com',
#  'Clark, Christopher;cclark@gmail.com',
#  'French, David;dfrench@gmail.com',
#  'Decleir, Marjorie;mdecleir@gmail.com',
#  'Dieterich, Serge;sdieterich@gmail.com',
#  'Espinoza, Nestor;nespinoza@gmail.com',
#  'Kumari, Nimisha;kumari@gmail.com',
#  'Revalski, Mitchell;mrevalski@gmail.com',
#  'Rowlands, Kate;krowlands@gmail.com',
#  'Watkins, Laura;lwatkins@gmail.com',
#  'Wu, John F.;',
#  'Hamanowicz, Aleksandra;',
#  'Gezari, Suvi;',
#  'Rickman, Emily;',
#  'Mehdipour, Missagh;mmehdipour@gmail.com',
#  'Nikolov, Nikolay;nnikolov@gmail.com',
#  'Por, Emiel H.;epor@gmail.com',
#  'Manjavacas, Elena;emanjavacas@gmail.com',
#  'Indriolo, Nick;nindriolo@gmail.com',
#  'Bennet, Paul;pbennet@gmail.com',
#  'Gull, Ted;tgull@gmail.com',
#  'Mingozzi, Matilde;ESA/AURA@gmail.com',
#  'Ntampaka, Michelle;mntampaka@gmail.com',
#  'Pierel, Justin;jpierel@gmail.com',
#  'Petric, Andreea;apetric@gmail.com',
#  'Schreier, Ethan;',
#  'Willman, Beth;',
#  'Hernandez, Svea;shernandez@gmail.com',
#  'Fischer, Travis;tfischer@gmail.com',
#  'Pegues, Jamila;jpegues@gmail.com',
#  'Murray, Claire;cmurray1@gmail.com',
#  'Larson, Kirsten;kilarson@gmail.com',
#  'Som, Debopam;dsom@gmail.com',
#  'Anand, Gagandeep;ganand@gmail.com',
#  'Flagey, Nicolas;nflagey@gmail.com',
#  'Jones, Logan;lojones@gmail.com',
#  'Tea, Mason V.;mtea@gmail.com',
#  'Dos Santos, Leonardo;ldsantos@gmail.com',
#  'Johnson, Christian I.;cjohnson1@gmail.com',
#  'Lucy, Adrian;alucy@gmail.com',
#  'Huwe, Paul;phuwe@gmail.com',
#  'Aguilar, Jonathan;jaguilar@gmail.com',
#  'Avila, Roberto;avila@gmail.com',
#  'Burger, Matthew;mburger@gmail.com',
#  'Cara, Mihai;mcara@gmail.com',
#  'Conroy, Kyle;kconroy@gmail.com',
#  'Filippazzo, Joe;jfilippazzo@gmail.com',
#  'Hami, Maryam;mhami@gmail.com',
#  'Hargis, Jonathan;jhargis@gmail.com',
#  'Jones, Amy;amjones@gmail.com',
#  'Marinelli, Mariarosa;mmarinelli@gmail.com',
#  'Monroe, TalaWanda;tmonroe@gmail.com',
#  'Pena-Guerrero, Maria;pena@gmail.com',
#  'Rodriguez, David;drodriguez@gmail.com',
#  'Ryon, Jenna;ryon@gmail.com',
#  'Sahoo, Ananya;asahoo@gmail.com',
#  'Wahlgren, Glenn;gwahlgren@gmail.com',
#  'Yoon, Jinmi;jyoon@gmail.com',
#  'Beaton, Rachael;rbeaton@gmail.com',
#  'Schlafly, Edward;eschlafly@gmail.com',
#  'Meena, Beena;bmeena@gmail.com',
#  'Jung, Intae;ijung@gmail.com',
#  'Morris, Brett;bmmorris@gmail.com',
#  'Hoch, Kielan;khoch@gmail.com',
#  'Evans, Christopher;chevans@gmail.com',
#  'Nota, Antonella;Nota@gmail.com',
#  'Sanchez,&nbsp; Javier;jsandez@gmail.com',
#  'Siebert, Matthew;msiebert@gmail.com',
#  'Sing, David;',
#  'Sharma, Sanjib;ssharma@gmail.com',
#  'Pagul,&nbsp;Amanda;apagul@gmail.com',
#  'Stark, David;dstark@gmail.com',
#  'Beckett,&nbsp;Alexander;abeckett@gmail.com',
#  'Tarantino,&nbsp;Elizabeth;etarantino@gmail.com',
#  'Gressier, Amelie;agressier@gmail.com',
#  'Bish, Hannah;hbish@gmail.com',
#  'Hawcroft, Calum;chawcroft@gmail.com',
#  'Shahbandeh, Melissa;mshahbandeh@gmail.com',
#  'Pourcelot, Raphael;rpourcelot@gmail.com',
#  'Berger, Travis;tberger@gmail.com',
#  'Bright, Stacey;bright@gmail.com',
#  'Goldman, Steve;sgoldman@gmail.com',
#  'Miller, Lauren;lmiller@gmail.com',
#  'Nguyen, Meiji;mnguyen@gmail.com',
#  'O&#39;Steen, Richard;rosteen@gmail.com',
#  'Pauly, Tyler;tpauly@gmail.com',
#  'Shaw, Richard;shaw@gmail.com',
#  'Spitzer, Isaac;ispitzer@gmail.com',
#  'Swaters, Richard;rswaters@gmail.com',
#  'Teodore, Mairan;mteodore@gmail.com',
#  'Todd, Connor;ctodd@gmail.com',
#  'Hasselquist, Sten;shasselquist@gmail.com',
#  'Lee, Janice C.&nbsp;;jlee@gmail.com',
#  'Betti, Sarah;sbetti@gmail.com',
#  'Steiger, Sarah;ssteiger@gmail.com',
#  'Vanderhoof, Brittany;bvanderhoof@gmail.com',
#  'Mishra, Sapna;smirshra@gmail.com',
#  'Coulter, David;dcoulter@gmail.com',
#  'Yung, Aaron;yung@gmail.com',
#  'Ranjan, Adarsh;aranjan@gmail.com',
#  'Alam, Munazza;malam@gmail.com',
#  'Lothringer, Joshua;jlothringer@gmail.com',
#  'Rodriguez, Jimena;jrodriguez@gmail.com',
#  'Carter, Aarynn;aacarter@gmail.com',
#  'Stroe, Andra;astroe@gmail.com',
#  ';iwong@gmail.com',
#  'Strampelli, Giovanni;gstrampelli@gmail.com',
#  'Gunasekera, Chamani;cgunasekera@gmail.com',
#  'Griggio, Massimo;mgriggio@gmail.com',
#  'Maschmann, Daniel;dmaschmann@gmail.com',
#  'Bidot, Alexis;abidot@gmail.com',
#  'DerKacy, James;jderkacy@gmail.com',
#  'Crespo Gomez, Alejandro;agomez@gmail.com',
#  'Fadda, Dario;dfadda@gmail.com',
#  'Ih, Jegug;jih@gmail.com',
#  'Rickards Vaught, Ryan;rrickardsvaught@gmail.com',
#  'Smercina, Adam;asmercina@gmail.com',
#  'Escala, Ivanna;iescala@gmail.com',
#  'Erba, Christiana;cerba@gmail.com',
#  'Hasan, Farhanul;fhasan@gmail.com',
#  'Biny, Sebastian;bsebastian@gmail.com',
#  'Crotts, Katie;kcrotts@gmail.com',
#  'Levy, Rebecca;rlevy@gmail.com',
#  'McQuinn, Kristen B. Wingfield;kmcquinn@gmail.com',
#  'Brandt, Timothy;tbrandt@gmail.com',
#  'Goovaerts, Ilias;igoovaerts@gmail.com',
#  'Madurowicz, Alexander;amadurowicz@gmail.com',
#  'D&#39;Orazio, Daniel;dorazio@gmail.com',
#  'Holmberg, Mans;mholmberg@gmail.com',
#  'Garcia del Valle Espinosa, Macarena;mgarciavalle@gmail.com',
#  'Diamond-Lowe, Hannah;hdiamondlowe@gmail.com',
#  'Soto, Christian;csoto@gmail.com',
#  'Lopez-Morales, Mercedes;mlopez-morales@gmail.com',
#  'Lotz, Jennifer;lotz@gmail.com',
#  'Norman, Colin;norman@gmail.com',
#  'H&ouml;rst, Sarah;sarah.horst@gmail.com',
#  'Noirot, Gael;gnoirot@gmail.com',
#  'Bushouse, Howard;hbushouse@gmail.com',
#  'Sosey, Megan;sosey@gmail.com']

# %%
# add @stsci.com to the string

real_mail= [name+"@stsci.com" for name in clean_mail]
real_mail
# Out:
# ['kalatalo@stsci.com',
#  'aloisi@stsci.com',
#  'jayander@stsci.com',
#  'tbeck@stsci.com',
#  'bellini@stsci.com',
#  'boeker@stsci.com',
#  'bohlin@stsci.com',
#  'mboyer@stsci.com',
#  'cbritt@stsci.com',
#  'tbrown@stsci.com',
#  'calamida@stsci.com',
#  'jcarlberg@stsci.com',
#  'stefano@stsci.com',
#  'chayer@stsci.com',
#  'cchen@stsci.com',
#  'marcoc@stsci.com',
#  'carolc@stsci.com',
#  'dcoe@stsci.com',
#  'gderosa@stsci.com',
#  'debes@stsci.com',
#  'dixon@stsci.com',
#  'ferguson@stsci.com',
#  'flanagan@stsci.com',
#  'afox@stsci.com',
#  'ofox@stsci.com',
#  'friedman@stsci.com',
#  'fruchter@stsci.com',
#  'fullerton@stsci.com',
#  'gennaro@stsci.com',
#  'kgilbert@stsci.com',
#  'golim@stsci.com',
#  'kgordon@stsci.com',
#  'goudfroo@stsci.com',
#  'jgreen@stsci.com',
#  'nagrogin@stsci.com',
#  'nhathi@stsci.com',
#  'ahenry@stsci.com',
#  'hines@stsci.com',
#  'bholler@stsci.com',
#  'bjames@stsci.com',
#  'kassin@stsci.com',
#  'keyes@stsci.com',
#  'koekemoer@stsci.com',
#  'gak@stsci.com',
#  'slamassa@stsci.com',
#  'dlaw@stsci.com',
#  'lawton@stsci.com',
#  'leitherer@stsci.com',
#  'nlevenson@stsci.com',
#  'long@stsci.com',
#  'lubow@stsci.com',
#  'mackenty@stsci.com',
#  'duccio@stsci.com',
#  'emarcucci@stsci.com',
#  'maca@stsci.com',
#  'pmcc@stsci.com',
#  'mclean@stsci.com',
#  'amaya@stsci.com',
#  'muzerol@stsci.com',
#  'nelan@stsci.com',
#  'anoriega@stsci.com',
#  'norman@stsci.com',
#  'pogle@stsci.com',
#  'osten@stsci.com',
#  'bosullivan@stsci.com',
#  'jegpeek@stsci.com',
#  'molly@stsci.com',
#  'mperrin@stsci.com',
#  'npirzkal@stsci.com',
#  'postman@stsci.com',
#  'proffitt@stsci.com',
#  'pueyo@stsci.com',
#  'mrafelski@stsci.com',
#  'mregan@stsci.com',
#  'inr@stsci.com',
#  'arest@stsci.com',
#  'ariess@stsci.com',
#  'robberto@stsci.com',
#  'duval@stsci.com',
#  'rryan@stsci.com',
#  'ksahu@stsci.com',
#  'rsankrit@stsci.com',
#  'sargent@stsci.com',
#  'sembach@stsci.com',
#  'sirianni@stsci.com',
#  'anand@stsci.com',
#  'gcsloan@stsci.com',
#  'lsmith@stsci.com',
#  'drs@stsci.com',
#  'tsohn@stsci.com',
#  'sonnentr@stsci.com',
#  'soummer@stsci.com',
#  'jstans@stsci.com',
#  'mstiavel@stsci.com',
#  'strolger@stsci.com',
#  'mplate@stsci.com',
#  'etollerud@stsci.com',
#  'tumlinson@stsci.com',
#  'valenti@stsci.com',
#  'marel@stsci.com',
#  'volk@stsci.com',
#  'dwelty@stsci.com',
#  'rlw@stsci.com',
#  'whitmore@stsci.com',
#  'wblair@stsci.com',
#  'lbradley@stsci.com',
#  'fleming@stsci.com',
#  'jgirard@stsci.com',
#  'skendrew@stsci.com',
#  'smullally@stsci.com',
#  'mutchler@stsci.com',
#  'sparks@stsci.com',
#  'cpacifici@stsci.com',
#  'zeidler@stsci.com',
#  'lucas@stsci.com',
#  'cclark@stsci.com',
#  'dfrench@stsci.com',
#  'mdecleir@stsci.com',
#  'sdieterich@stsci.com',
#  'nespinoza@stsci.com',
#  'kumari@stsci.com',
#  'mrevalski@stsci.com',
#  'krowlands@stsci.com',
#  'lwatkins@stsci.com',
#  'jowu@stsci.com',
#  'mmehdipour@stsci.com',
#  'nnikolov@stsci.com',
#  'epor@stsci.com',
#  'emanjavacas@stsci.com',
#  'nindriolo@stsci.com',
#  'pbennet@stsci.com',
#  'tgull@stsci.com',
#  'mmingozzi@stsci.com',
#  'mntampaka@stsci.com',
#  'jpierel@stsci.com',
#  'apetric@stsci.com',
#  'shernandez@stsci.com',
#  'tfischer@stsci.com',
#  'jpegues@stsci.com',
#  'cmurray1@stsci.com',
#  'kilarson@stsci.com',
#  'dsom@stsci.com',
#  'ganand@stsci.com',
#  'nflagey@stsci.com',
#  'lojones@stsci.com',
#  'mtea@stsci.com',
#  'ldsantos@stsci.com',
#  'cjohnson1@stsci.com',
#  'alucy@stsci.com',
#  'phuwe@stsci.com',
#  'jaguilar@stsci.com',
#  'avila@stsci.com',
#  'mburger@stsci.com',
#  'mcara@stsci.com',
#  'kconroy@stsci.com',
#  'jfilippazzo@stsci.com',
#  'mhami@stsci.com',
#  'jhargis@stsci.com',
#  'amjones@stsci.com',
#  'mmarinelli@stsci.com',
#  'tmonroe@stsci.com',
#  'pena@stsci.com',
#  'drodriguez@stsci.com',
#  'ryon@stsci.com',
#  'asahoo@stsci.com',
#  'gwahlgren@stsci.com',
#  'jyoon@stsci.com',
#  'rbeaton@stsci.com',
#  'eschlafly@stsci.com',
#  'bmeena@stsci.com',
#  'ijung@stsci.com',
#  'bmmorris@stsci.com',
#  'khoch@stsci.com',
#  'chevans@stsci.com',
#  'Nota@stsci.com',
#  'jsandez@stsci.com',
#  'msiebert@stsci.com',
#  'ssharma@stsci.com',
#  'apagul@stsci.com',
#  'dstark@stsci.com',
#  'abeckett@stsci.com',
#  'etarantino@stsci.com',
#  'agressier@stsci.com',
#  'hbish@stsci.com',
#  'chawcroft@stsci.com',
#  'mshahbandeh@stsci.com',
#  'rpourcelot@stsci.com',
#  'tberger@stsci.com',
#  'bright@stsci.com',
#  'sgoldman@stsci.com',
#  'lmiller@stsci.com',
#  'mnguyen@stsci.com',
#  'rosteen@stsci.com',
#  'tpauly@stsci.com',
#  'shaw@stsci.com',
#  'ispitzer@stsci.com',
#  'rswaters@stsci.com',
#  'mteodore@stsci.com',
#  'ctodd@stsci.com',
#  'shasselquist@stsci.com',
#  'jlee@stsci.com',
#  'sbetti@stsci.com',
#  'ssteiger@stsci.com',
#  'bvanderhoof@stsci.com',
#  'smirshra@stsci.com',
#  'dcoulter@stsci.com',
#  'yung@stsci.com',
#  'aranjan@stsci.com',
#  'malam@stsci.com',
#  'jlothringer@stsci.com',
#  'jrodriguez@stsci.com',
#  'aacarter@stsci.com',
#  'astroe@stsci.com',
#  'iwong@stsci.com',
#  'gstrampelli@stsci.com',
#  'cgunasekera@stsci.com',
#  'mgriggio@stsci.com',
#  'dmaschmann@stsci.com',
#  'abidot@stsci.com',
#  'jderkacy@stsci.com',
#  'agomez@stsci.com',
#  'dfadda@stsci.com',
#  'jih@stsci.com',
#  'rrickardsvaught@stsci.com',
#  'asmercina@stsci.com',
#  'iescala@stsci.com',
#  'cerba@stsci.com',
#  'fhasan@stsci.com',
#  'bsebastian@stsci.com',
#  'kcrotts@stsci.com',
#  'rlevy@stsci.com',
#  'kmcquinn@stsci.com',
#  'tbrandt@stsci.com',
#  'igoovaerts@stsci.com',
#  'amadurowicz@stsci.com',
#  'dorazio@stsci.com',
#  'mholmberg@stsci.com',
#  'mgarciavalle@stsci.com',
#  'hdiamondlowe@stsci.com',
#  'csoto@stsci.com',
#  'lotz@stsci.com',
#  'norman@stsci.com',
#  'gnoirot@stsci.com',
#  'hbushouse@stsci.com',
#  'sosey@stsci.com']

# %%
len(results)
# Out:
# 260

# %%
# Match names inside <td style="width: 15%">, with or without <a>
name_re = re.compile(
    r'<td[^>]*style="[^"]*width:\s*15%;[^"]*"[^>]*>\s*(?:<a[^>]*>)?([^<]+)(?:</a>)?\s*</td>',
    re.IGNORECASE
)

# Match emails in any of these:
# - <td style="width: 10%;">email</td>
# - <td>email<br>
# - <p>email<br>
mail_re = re.compile(
    r'(?:<td[^>]*style="[^"]*width:\s*10%;[^"]*"[^>]*>|<td[^>]*>|<p[^>]*>)\s*([^<]+)',
    re.IGNORECASE
)

# Extract rows
rows = re.findall(r'<tr.*?>.*?</tr>', redirectory, flags=re.DOTALL | re.IGNORECASE)

results2 = []

for row in rows:
    name_match = name_re.search(row)
    mail_match = mail_re.search(row)
    name = name_match.group(1).strip() if name_match else ''
    mail = mail_match.group(1).strip() if mail_match else ''
    results2.append(f"{name};{mail}")
